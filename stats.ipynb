# %%
import pandas as pd

# %%
df = pd.read_csv('allshootings.csv')
df
# Out:
#       Incident ID      Incident Date           State  \
# 0         2509362   January 23, 2023        Illinois
# 1         2509663   January 23, 2023      California
# 2         2508683   January 22, 2023     Mississippi
# 3         2508370   January 22, 2023       Louisiana
# 4         2508522   January 22, 2023       Louisiana
# ...           ...                ...             ...
# 1995      1579266  December 24, 2019       Louisiana
# 1996      1594317  December 24, 2019        Illinois
# 1997      1579220  December 24, 2019  North Carolina
# 1998      1577577  December 22, 2019        Maryland
# 1999      1577688  December 22, 2019       Minnesota
#
#                       City Or County                          Address  \
# 0                            Chicago       2900 block of East 78th St
# 1                      Half Moon Bay               12761 San Mateo Rd
# 2     Robinsonville (Tunica Resorts)            1010 Casino Center Dr
# ...
